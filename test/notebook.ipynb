# %%
import alduin

# %%
dut = alduin.init()

# %%
dir(dut.driver)
# Out:
# ['AC_OFF',
#  'AC_ON',
#  '__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_absent_extensions',
#  '_add_commands',
#  '_authenticator_id',
#  '_check_if_window_handle_is_current',
#  '_extensions',
#  '_file_detector',
#  '_get_cdp_details',
#  '_is_protocol',
#  '_is_remote',
#  '_is_runtime_protocol',
#  '_mobile',
#  '_script',
#  '_shadowroot_cls',
#  '_start_bidi',
#  '_switch_to',
#  '_unwrap_value',
#  '_update_command_executor',
#  '_web_element_cls',
# ...

# %%
from appium.webdriver.common.appiumby import AppiumBy
dut.driver.find_elements(by=AppiumBy.XPATH, value='//android.widget.ScrollView')[-1].get_attribute('bounds')
# Out:
# '[0,727][1080,2280]'

# %%
scroller = dut.driver.find_elements(by=AppiumBy.XPATH, value='//android.widget.ScrollView')[-1].get_attribute('bounds')
dut.driver.swipe(540,2280,727,540,1000)
# Out:
# <appium.webdriver.webdriver.WebDriver (session="7efe440f-3868-4ba8-a3a2-14ef18241aa5")>
